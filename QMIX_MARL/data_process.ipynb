import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# 初始化图
G = nx.DiGraph()  # 有向图



# 可能的节点位置
positions =  {key+1: value for key, value in enumerate(centers) } # {1: (1, 2), 2: (3, 5), 3: (6, 7)}

fixed_cell = [(1,2),(2,3),(3,4),(4,5),(38,37),(37,36),(36,35),(35,34),(34,33),(33,32),(55,54),(54,53),(53,52)
                             ,(52,51),(23,22),(22,21),(21,20),(20,19),(19,18),(68,69),(26,71),(14, 15), (16, 15), (15, 70)]
sigal_effect_cells = [{1: [(31, 32), (32, 39), (39, 40), (40, 41)], 2: [(40, 39), (39, 32), (32, 31), (31, 30)]},
                          # agent1
                          {1: [(41, 42), (42, 43), (43, 44), (44, 45)], 3: [(44, 43), (43, 42), (42, 41), (41, 40)]},
                          # agent2
                          {1: [(45, 46), (46, 47), (47, 48)], 3: [(47, 46), (46, 45), (45, 44)]},  # agent3
                          {1: [(48, 49), (49, 50), (50, 51)], 3: [(50, 49), (49, 48), (48, 47)]},  # agent4
                          {2: [(51, 56), (56, 57)], 3: [(56, 51), (51, 50)]},  # agent5
                          {2: [(57, 58), (58, 59)], 4: [(58, 57), (57, 56)]},  # agent6
                          {2: [(59, 60), (60, 61)], 4: [(60, 59), (59, 58)]},  # agent7
                          {2: [(61, 62), (62, 63), (63, 18)], 4: [(63, 62), (62, 61), (61, 60)]},  # agent8
                          {3: [(18, 17), (17, 16)], 4: [(17, 18), (18, 63)]},  # agent9
                          #{4: [(14, 15), (16, 15), (15, 70)]},  # agent10  1: [(14, 15), (15, 16), (16, 17)], 3: [(16, 15), (15, 14), (14, 13)],
                          {1: [(13, 14)], 4: [(13, 12)]},  # agent11
                          {1: [(64, 11), (11, 12), (12, 13)], 3: [(64, 11), (11, 12), (12, 13)],
                           4: [(12, 11), (11, 64), (64, 65)]},  # agent12
                          {1: [(10, 11)], 3: [(10, 9)]},  # agent13
                          {1: [(7, 8), (8, 9), (9, 10)], 3: [(9, 8), (8, 7), (7, 6)]},  # agent14
                          {3: [(24, 5), (5, 6), (6, 7)], 4: [(6, 5), (5, 24), (24, 25)]},  # agent15
                          {2: [(25, 24)], 4: [(25, 26)]},  # agent16
                          {2: [(28, 27), (27, 26)], 4: [(27, 28), (28, 29)]},  # agent17
                          {2: [(30, 29), (29, 28)], 4: [(29, 30), (30, 31)]},  # agent18
                          {3: [(65, 66), (66, 67), (67, 68)], 2: [(67, 66), (66, 65), (65, 64)]},  # agent19
                          ]




# 所有时间步的边列表
edges_by_time = [
    [(1, 2), (2, 3)],
    [(2, 3), (3, 1)],
    [(3, 1), (1, 2)]
]

# 绘图设置
fig, ax = plt.subplots(figsize=(8, 5))

def update(num):
    ax.clear()  # 清除旧的图形
    G.clear()   # 清除旧的边和节点
    G.add_nodes_from(positions)
    G.add_edges_from(edges_by_time[num % len(edges_by_time)])  # 添加新的边
    nx.draw(G, pos=positions, with_labels=True, node_color='black', edge_color='black',
            node_size=40, font_size=6, font_color='white', ax=ax)
    ax.set_title(f"Time: {num}")

# 创建动画
ani = FuncAnimation(fig, update, frames=6, interval=1000, repeat=True)

# 保存为 GIF
ani.save('graph_animation.gif', writer='imagemagick', fps=1)

# 显示图形
plt.show()
